# %%
import pandas as pd, matplotlib.pyplot as plt, pylab as pl, numpy as np
libPath = 'project1/scripts'
import sys
if not libPath in sys.path: sys.path.append(libPath)
from implementations import *
# Use a subset 
df = pd.read_csv("train.csv")
df.head()
# Out:
#        Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  100000          s       138.470                       51.655        97.827
# 1  100001          b       160.937                       68.768       103.235
# 2  100002          b      -999.000                      162.172       125.953
# 3  100003          b       143.905                       81.417        80.943
# 4  100004          b       175.864                       16.915       134.805
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0    27.980                  0.91           124.711                2.666
# 1    48.146               -999.00          -999.000             -999.000
# 2    35.635               -999.00          -999.000             -999.000
# 3     0.414               -999.00          -999.000             -999.000
# 4    16.405               -999.00          -999.000             -999.000
#
# ...

# %%
# Calculate the correlation between Prediction and various Feature 
y,inputs,id=read_clean_csv()
cross_correlate_vec = []
for i in range(29):
# Cross-correlation of two 1-dimensional sequences, c_{av}[k] = sum_n a[n+k] * conj(v[n])
    cross_correlate_vec.append(np.correlate(df.iloc[:,1], df.iloc[:,2+i])[0])

coef_vec = []
for i in range(29):
# Pearson product-moment correlation coefficients
    coef_vec.append(np.corrcoef(df.iloc[:,1], df.iloc[:,2+i])[0,1])

# print(coef_vec)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-68f6d7fd4f2d> in <module>()
#       4 for i in range(29):
#       5 # Cross-correlation of two 1-dimensional sequences, c_{av}[k] = sum_n a[n+k] * conj(v[n])
# ----> 6     cross_correlate_vec.append(np.correlate(df.iloc[:,1], df.iloc[:,2+i])[0])
#       7
#       8 coef_vec = []
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
# ...

# %%
# plt.scatter(cross_correlate_vec, coef_vec)

plt.scatter(range(29), np.abs(coef_vec))
plt.grid
plt.xlabel("Feature number")
plt.ylabel("Pearson product-moment correlation coef")
# plt.title("Pearson Correlation coefficient of features against prediction")
# plt.savefig("Figures/feature_corr_coef_2")
plt.show()
plt.savefig('fig_corr_coef1',format=eps)
# Note the difference in y-axis scale 
plt.scatter(range(29), np.abs(cross_correlate_vec))
plt.grid
plt.xlabel("Feature number")
plt.ylabel("Absolute value of cross correlation")
# plt.title("Correlation coefficient of features against prediction")
plt.show()

# print(coef_vec)
# print(cross_correlate_vec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-150bdc35844b> in <module>()
#       1 # plt.scatter(cross_correlate_vec, coef_vec)
#       2
# ----> 3 plt.scatter(range(29), np.abs(coef_vec))
#       4 plt.grid
#       5 plt.xlabel("Feature number")
#
# NameError: name 'coef_vec' is not defined

# %%
# get the number of features that have coef value greater than 10 
coef_vec_abs = np.abs(coef_vec)

np.sum(coef_vec_abs>0.1)

feature_list_ind = [i for i, x in enumerate(coef_vec_abs) if x>0.1]

# feature list, 0 indexed starting from DER_mass_MMC
print(feature_list_ind)

# updated feature list when using the entire training set 
# [1, 3, 4, 5, 6, 8, 10, 11, 12, 13, 22]

#original feature list when using a sample of the training set 
# [ 1,  5,  8, 10, 11, 12, 13, 17, 22, 25]
# Out:
# 11

# %%
# import seaborn as sns 

# feature_sets = pd.concat([df['Prediction'], df.iloc[:,19:31]], axis=1)

# 30 usefule features: 3x10 

# sns.set(style="ticks")
# sns_plot = sns.pairplot(pd.concat([df['Prediction'], df[df.columns[[feature_list_ind]]]], axis=1), hue="Prediction")
# image_title="scatter_matrix_train"+str(i)

# %%
# correlation matrix for selected features 
feature_num = len(feature_list_ind)
corr_matrix = np.array([[0.1 for i in range(feature_num)] for j in range(feature_num)])
for i in range(feature_num): 
    foo = feature_list_ind[i]
    for j in range(feature_num): 
        bar = feature_list_ind[j]
# offset by 2, since the feature_list_ind is 0 based starting from DER_mass 
        corr_matrix[i][j]=np.corrcoef(df.iloc[:,2+foo], df.iloc[:,2+bar])[0,1]

# %%
# print(coef_matrix)
# Feature 0-10 corresponding to feature val in feature_list_ind, not in original table
plt.imshow(np.abs(corr_matrix), interpolation='nearest')
plt.title("Correlation Coef of Selective Features")
plt.colorbar()
plt.show()

# %%
# Correlation coefficient matrix for all features (from Prediction to the last one)
corr_matrix_full = np.array([[0.1 for i in range(31)] for j in range(31)])
for i in range(31): 
    for j in range(31): 
        corr_matrix_full[i][j]=np.corrcoef(df.iloc[:,i+1], df.iloc[:,j+1])[0,1]

plt.imshow(np.abs(corr_matrix_full), interpolation='nearest', cmap='winter')
plt.title("Correlation Coefficient for All Features")
plt.colorbar()
plt.show()  

# plt.savefig("Figures/feature_corr_coef_all")

# %%
from numpy import linalg as LA

w,v = LA.eig(np.abs(corr_matrix_full))

print("Eigenvalues",w)
print("Eigenvectors", v)
# Out:
# Eigenvalues [ 6.4476  3.2015  2.5614  1.8353  1.7895  1.6578  1.5214  1.2888 -0.2057
#   1.0516  1.025   0.9677  0.948  -0.0298  0.0141  0.0725  0.099   0.1667
#   0.1598  0.2378  0.8019  0.7504  0.67    0.6459  0.6202  0.5866  0.5373
#   0.3543  0.4298  0.3991  0.3944]
# Eigenvectors [[-7.7659e-02  2.6649e-01 -2.5267e-02 -1.0099e-02 -7.4387e-03 -6.5538e-02
#   -8.1000e-02  4.0943e-01  1.5518e-02  3.0740e-01  1.6401e-03 -2.9918e-02
#    6.4773e-03 -5.4022e-02  7.5344e-03 -3.9514e-02 -1.4845e-02  9.1816e-02
#    2.2529e-02 -2.2337e-02 -6.0250e-02  2.7133e-03  1.2301e-01  7.3786e-01
#   -3.1806e-02 -9.5567e-02  7.0041e-02 -4.1746e-02 -2.1401e-01 -8.9413e-02
#    2.7238e-03]
#  [-7.7577e-02  1.9511e-02 -4.8072e-01  1.4256e-02  6.0345e-04  6.2526e-02
#    4.1343e-01 -1.6318e-01  4.1523e-02  4.7681e-02 -6.4207e-03 -4.6288e-03
#   -8.0669e-03  3.5155e-01 -7.4011e-03 -1.8958e-01  5.4536e-01 -2.5186e-02
#   -1.4736e-01  8.7307e-02  3.6072e-02 -6.5003e-04  2.0889e-02  1.2888e-01
# ...

# %%
# Covariance coefficient matrix for all features (from Prediction to the last one)
cov_matrix_full = np.array([[0.1 for i in range(31)] for j in range(31)])
for i in range(31): 
    for j in range(31): 
        cov_matrix_full[i][j]=np.cov(df.iloc[:,i+1], df.iloc[:,j+1])[0,1]

plt.imshow(np.abs(cov_matrix_full), interpolation='nearest', cmap='winter')
plt.title("Covariance Coefficient for All Features")
plt.colorbar()
plt.show()  

w,v = LA.eig(np.abs(cov_matrix_full))

print("Eigenvalues",w)
print("Eigenvectors", v)

# cross_correlate_vec = []
# for i in range(29):
#     cross_correlate_vec.append(np.correlate(df.iloc[:,1], df.iloc[:,2+i])[0])

# plt.imshow(np.abs(corr_matrix_full), interpolation='nearest', cmap='winter')
# plt.colorbar()
# plt.show()  
# plt.savefig("Figures/feature_corr_coef_all")

# print(np.cov(df.iloc[:,1], df.iloc[:,3])[0,1])
# Out:
# Eigenvalues [ 6.4475  3.2006  2.5615  1.8353  1.7895  1.6578  1.5214  1.288  -0.2057
#   1.0512  1.025   0.9677  0.948  -0.0298  0.8019  0.0141  0.0725  0.099
#   0.1667  0.1598  0.2378  0.7504  0.67    0.6444  0.6203  0.5866  0.5373
#   0.3543  0.4298  0.3991  0.3944]
# Eigenvectors [[-7.7440e-02 -2.6565e-01 -2.5206e-02  1.0048e-02  7.3990e-03  6.5129e-02
#    8.0385e-02 -4.0735e-01 -1.5536e-02 -3.0694e-01 -1.6613e-03  2.9952e-02
#   -6.4769e-03 -5.4122e-02 -5.9777e-02  7.5502e-03 -3.9612e-02 -1.4884e-02
#    9.2101e-02  2.2617e-02 -2.2423e-02 -2.6787e-03 -1.1620e-01 -7.3970e-01
#    3.3685e-02  9.7952e-02 -7.0994e-02 -4.2015e-02 -2.1546e-01 -9.0194e-02
#    2.7539e-03]
#  [-7.7579e-02 -1.9527e-02 -4.8073e-01 -1.4242e-02 -5.9166e-04 -6.2375e-02
#   -4.1335e-01  1.6382e-01 -4.1524e-02 -4.6951e-02  6.4206e-03  4.5881e-03
#    8.0764e-03  3.5154e-01  3.6210e-02 -7.4008e-03 -1.8957e-01  5.4536e-01
#   -2.5142e-02 -1.4736e-01  8.7301e-02  6.5867e-04 -1.9617e-02 -1.2872e-01
# ...
