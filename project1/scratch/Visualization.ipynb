# %%
# Script to visualize the data

# %%
import pandas as pd, matplotlib.pyplot as plt, pylab as pl

# %%
# read in the training and testing data
# Substitute with the helper functions later 
df_tr = pd.read_csv("train.csv")[0:50]
# df_tr = pd.read_csv("train.csv")
# df_te = pd.read_csv("test.csv")

# %%
df_tr
# Out:
#         Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# 0   100000          s       138.470                       51.655
# 1   100001          b       160.937                       68.768
# 2   100002          b      -999.000                      162.172
# 3   100003          b       143.905                       81.417
# 4   100004          b       175.864                       16.915
# 5   100005          b        89.744                       13.550
# 6   100006          s       148.754                       28.862
# 7   100007          s       154.916                       10.418
# 8   100008          b       105.594                       50.559
# 9   100009          s       128.053                       88.941
# 10  100010          b      -999.000                       86.240
# 11  100011          b       114.744                       10.286
# 12  100012          b       145.297                       64.234
# ...

# %%
# df_te.head()
# Out:
#        Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  350000          ?      -999.000                       79.589        23.916
# 1  350001          ?       106.398                       67.490        87.949
# 2  350002          ?       117.794                       56.226        96.358
# 3  350003          ?       135.861                       30.604        97.288
# 4  350004          ?        74.159                       82.772        58.731
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0     3.036              -999.000          -999.000             -999.000
# 1    49.994              -999.000          -999.000             -999.000
# 2     4.137              -999.000          -999.000             -999.000
# 3     9.104              -999.000          -999.000             -999.000
# 4    89.646                 1.347           536.663               -0.339
#
# ...

# %%
df_tr.columns
# Out:
# Index(['Id', 'Prediction', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt'],
#       dtype='object')

# %%
# Get the number of unique elements for each feature  
df_tr.nunique()
# Out:
# Id                             50
# Prediction                      2
# DER_mass_MMC                   44
# DER_mass_transverse_met_lep    50
# DER_mass_vis                   50
# DER_pt_h                       50
# DER_deltaeta_jet_jet           16
# DER_mass_jet_jet               16
# DER_prodeta_jet_jet            16
# DER_deltar_tau_lep             49
# DER_pt_tot                     50
# DER_sum_pt                     50
# DER_pt_ratio_lep_tau           49
# DER_met_phi_centrality         43
# DER_lep_eta_centrality         15
# PRI_tau_pt                     50
# PRI_tau_eta                    50
# PRI_tau_phi                    48
# PRI_lep_pt                     50
# PRI_lep_eta                    50
# PRI_lep_phi                    50
# PRI_met                        50
# PRI_met_phi                    50
# PRI_met_sumet                  50
# PRI_jet_num                     4
# PRI_jet_leading_pt             27
# PRI_jet_leading_eta            27
# ...

# %%
df_tr['Prediction'].unique()
# Create a dictionary to replace values of Prediction with numerical values 
dict_tr = dict(s=1, b=0)

# Apply the dictionary to the dataset 
df_tr = df_tr.replace(dict_tr, regex=True).astype(int)
df_tr.head()
# Out:
#        Id  Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# 0  100000           1           138                           51
# 1  100001           0           160                           68
# 2  100002           0          -999                          162
# 3  100003           0           143                           81
# 4  100004           0           175                           16
#
#    DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# 0            97        27                     0               124
# 1           103        48                  -999              -999
# 2           125        35                  -999              -999
# 3            80         0                  -999              -999
# 4           134        16                  -999              -999
#
#    DER_prodeta_jet_jet  DER_deltar_tau_lep       ...        PRI_met_phi  \
# 0                    2                   3       ...                  0
# ...

# %%
# create a dataframe that contains a subset of the original dataframe that we want to test for 
# df_mmc = df_tr[['Id','Prediction', 'DER_mass_MMC']]

# Scatter plot of DER_mass_MMC and Prediction
# print(df_tr.columns[2:])
# df_tr.plot.scatter(x='DER_mass_MMC', y='Prediction')
# df_tr.plot.scatter(x='DER_mass_transverse_met_lep', y='Prediction')

for i in df_tr.columns[2:]:
    df_tr.plot.scatter(x=i, y='Prediction')
# Out:
# /Users/ztian/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# Remove outlier (-999) from DER_mass_MMC 


df_tr[df_tr['Prediction'] == 1]["PRI_met"].hist()
# Out:
#                   Id  Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count      21.000000        21.0     21.000000                    21.000000
# mean   100028.333333         1.0    131.761905                    36.142857
# std        14.568230         0.0     21.915530                    23.484645
# min    100000.000000         1.0     95.000000                     0.000000
# 25%    100017.000000         1.0    120.000000                    22.000000
# 50%    100031.000000         1.0    129.000000                    32.000000
# 75%    100039.000000         1.0    138.000000                    51.000000
# max    100049.000000         1.0    201.000000                    88.000000
#
#        DER_mass_vis    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count     21.000000   21.000000             21.000000         21.000000
# mean      88.095238   65.904762           -522.333333       -321.952381
# ...

# %%
df_tr[df_tr['Prediction'] == 0].describe()
# Out:
#                   Id  Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count      29.000000        29.0     29.000000                    29.000000
# mean   100021.724138         0.0   -157.034483                    55.620690
# std        14.187259         0.0    484.371056                    35.752536
# min    100001.000000         0.0   -999.000000                     4.000000
# 25%    100011.000000         0.0     27.000000                    31.000000
# 50%    100020.000000         0.0     90.000000                    62.000000
# 75%    100033.000000         0.0    123.000000                    81.000000
# max    100048.000000         0.0    175.000000                   162.000000
#
#        DER_mass_vis    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count     29.000000   29.000000             29.000000         29.000000
# mean      76.827586   32.724138           -826.379310       -786.310345
# ...

# %%
df_tr[df_tr['Prediction'] == 1]["PRI_met"].hist()

# %%
df_tr[df_tr['Prediction'] == 0]["PRI_met"].hist()
