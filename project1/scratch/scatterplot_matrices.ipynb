# %%
import pandas as pd, matplotlib.pyplot as plt, pylab as pl 

# Use a subset 
df = pd.read_csv("clean_train_data.csv")[0:100]

# %%
import seaborn as sns 

# feature_sets = pd.concat([df['Prediction'], df.iloc[:,19:31]], axis=1)

# 30 usefule features: 3x10 

sns.set(style="ticks")
for i in range(10): 
    # index 2 to 31
    ind_start = 2+i*3
    sns_plot = sns.pairplot(pd.concat([df['Prediction'], df.iloc[:,ind_start:(ind_start+3)]], axis=1), hue="Prediction")
    image_title="scatter_matrix_train"+str(i)
    sns_plot.savefig("Figures/"+image_title)
